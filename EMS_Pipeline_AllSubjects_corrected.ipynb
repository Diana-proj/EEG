# %%
import mne

import numpy as np
import mne
from mne.preprocessing import ICA
import matplotlib.pyplot as plt

# %%
import os

os.chdir('/Users/sergeiukhov/Documents/EEGNEW/')

print(os.getcwd())
# Out:
# /Users/sergeiukhov/Documents/EEGNEW

# %%
file_path = "/Users/sergeiukhov/Documents/EEGNEW/sub-02"
print(os.path.exists(file_path))  # This should print True if the file exists
# Out:
# True

# %%
import os
import numpy as np
import mne
import matplotlib.pyplot as plt
from mne_bids import BIDSPath, read_raw_bids

event_id = {
    'normal': 1,   
    'conflict': 2  
}

def process_subject(subject_id, session, bids_root):
    
    # Define file paths
    bids_path = BIDSPath(
        subject=subject_id, session=session, task="PredictionError", suffix="eeg", extension=".vhdr", root=bids_root
    )
    
    # Load raw data
    raw = read_raw_bids(bids_path)

    # Preprocessing steps
    raw.annotations.onset -= 0.063  # Adjust for EEG setup delay
    raw_resampled = raw.copy().resample(sfreq=250, npad="auto")  # Resample
    raw_filtered = raw_resampled.filter(l_freq=1.0, h_freq=124.0).notch_filter(freqs=50)  # Bandpass + Notch filter
    raw_referenced = raw_filtered.set_eeg_reference(ref_channels="average").set_montage("standard_1020")  # Re-reference
    
    # Step 5: Extract events based on annotations
    events = []
    for annot in raw_referenced.annotations:
        print(f"Processing annotation: {annot['description']}")
        if 'normal_or_conflict:normal' in annot['description']:
            events.append([int(annot['onset'] * raw_referenced.info['sfreq']), 0, event_id['normal']])
        elif 'normal_or_conflict:conflict' in annot['description']:
            events.append([int(annot['onset'] * raw_referenced.info['sfreq']), 0, event_id['conflict']])
        else:
            print("Skipping irrelevant annotation:", annot['description'])
    events = np.array(events, dtype=int)

    # Extract epochs
    epochs = mne.Epochs(
        raw_referenced, events, event_id=event_id, tmin=-0.3, tmax=0.7,
        baseline=(-0.3, 0), preload=True, event_repeated='merge'
    )
    print(f"Total epochs: {len(epochs)}")

    # Compute Mean Absolute Amplitude for Each Epoch
    epoch_data = epochs.get_data()  # Shape: (n_epochs, n_channels, n_times)
    mean_amplitudes = np.mean(np.abs(epoch_data), axis=(1, 2))  # Mean over channels and time

    # Rank Epochs by Mean Amplitude
    ranked_indices = np.argsort(mean_amplitudes)  

    # Keep 85% of the Cleanest Epochs
    percentage = 85
    n_epochs_to_keep = int(len(epochs) * (percentage / 100))
    selected_indices = ranked_indices[:n_epochs_to_keep]  # Select top 85% clean epochs

    # Create Clean Epochs and Apply ICA
    clean_epochs = epochs[selected_indices]

    ica = ICA(n_components=10, method='picard', random_state=42, max_iter=5000)
    ica.fit(clean_epochs)

    ica.plot_components()

    from mne_icalabel import label_components

    # Step 6: Use ICLabel for automatic component classification
    labels = label_components(raw_referenced, ica, method='iclabel')

    print("ICLabel Results:")
    for idx, (label, prob) in enumerate(zip(labels['labels'], labels['y_pred_proba'])):
        print(f"Component {idx}: {label} (Probability: {prob:.2f})")

    # Automatically mark bad components for exclusion
    bad_ics = [idx for idx, label in enumerate(labels['labels'])
            if label in ('eye blink', 'muscle artifact', 'line_noise')]

    ica.exclude = bad_ics  # Mark components for exclusion

    ica.apply(raw_referenced)

    raw_referenced.set_meas_date(None)

    #raw_referenced.save(f"cleaned_data_{subject_id}_{session}.fif", overwrite=True)

    # Step 7: Filter ERP data with 0.2 Hz high-pass and 35 Hz low-pass
    raw_referenced = raw_referenced.copy().filter(l_freq=0.2, h_freq=35.0)

    # Step 9: Reject 10% of the noisiest epochs based on signal amplitude
    epoch_data = epochs.get_data()  # Shape: (n_epochs, n_channels, n_times)
    mean_amplitudes = np.mean(np.abs(epoch_data), axis=(1, 2))  # Compute mean amplitude for each epoch
    threshold = np.percentile(mean_amplitudes, 90)  # Top 10% noisy epochs
    clean_epochs = epochs[mean_amplitudes < threshold]

    # Step 10: Focus analyses on selected electrodes 
    frontal_channels = ['Fz', 'Cz', 'Fp1', 'FC1', 'FC2']
    clean_epochs.pick_channels(frontal_channels)

    # Step 11: Extract ERP negativity peaks (minimum peak) in the 100–300 ms time window
    time_window = (0.1, 0.3)  # 100–300 ms
    negativity_peaks = {}

    for ch_name in frontal_channels:
        channel_idx = clean_epochs.ch_names.index(ch_name)
        erp_data = clean_epochs.average().data[channel_idx]
        times = clean_epochs.times

        # Extract the data within the time window
        mask = (times >= time_window[0]) & (times <= time_window[1])
        time_window_data = erp_data[mask]
        time_window_times = times[mask]

        # Find the minimum (negative) peak
        peak_idx = np.argmin(time_window_data)
        peak_time = time_window_times[peak_idx]
        peak_amplitude = time_window_data[peak_idx]

        negativity_peaks[ch_name] = (peak_time, peak_amplitude)
        print(f"Channel {ch_name}: Negativity peak at {peak_time:.3f} s with amplitude {peak_amplitude:.3f} µV")


    epochs_match = epochs['normal']
    epochs_mismatch = epochs['conflict']
    print(f"Match trials: {len(epochs_match)}, Mismatch trials: {len(epochs_mismatch)}")


    erp_normal = epochs_match.average()
    erp_conflict = epochs_mismatch.average()

    return erp_normal.data, erp_conflict.data



bids_root = "/Users/sergeiukhov/Documents/EEGNEW"
subjects = ["02", "03","06","07","08","11","12","13","14","15","16"]
sessions = ["EMS", "Vibro", "Visual"]  

channel = 'Fz'



# Initialize storage for each session
all_normal_visual, all_conflict_visual = [], []
all_normal_ems, all_conflict_ems = [], []
all_normal_vibro, all_conflict_vibro = [], []

# Process subjects and sessions
for subject in subjects:
    for session in sessions:
        try:
            normal_data, conflict_data = process_subject(subject, session, bids_root)
            print(f"Shape of normal_data for subject {subject}, session {session}: {normal_data.shape}")
            print(f"Shape of conflict_data for subject {subject}, session {session}: {conflict_data.shape}")
            
            # Append data to respective session lists
            if session == "Visual":
                all_normal_visual.append(normal_data)
                all_conflict_visual.append(conflict_data)
            elif session == "EMS":
                all_normal_ems.append(normal_data)
                all_conflict_ems.append(conflict_data)
            elif session == "Vibro":
                all_normal_vibro.append(normal_data)
                all_conflict_vibro.append(conflict_data)
        except FileNotFoundError:
            print(f"File not found for subject {subject}, session {session}. Skipping this session.")
            continue

# Compute averages for each session
avg_data = {
    "Visual": {
        "normal": np.mean(all_normal_visual, axis=0),
        "conflict": np.mean(all_conflict_visual, axis=0),
    },
    "EMS": {
        "normal": np.mean(all_normal_ems, axis=0),
        "conflict": np.mean(all_conflict_ems, axis=0),
    },
    "Vibro": {
        "normal": np.mean(all_normal_vibro, axis=0),
        "conflict": np.mean(all_conflict_vibro, axis=0),
    },
}

# Define the target channel and prepare time vector
raw_example = read_raw_bids(BIDSPath(
    subject=subjects[0], session=sessions[0], task="PredictionError", suffix="eeg", extension=".vhdr", root=bids_root
))
channel_idx = raw_example.info['ch_names'].index(channel)
times = np.linspace(-0.3, 0.7, avg_data["Visual"]["normal"].shape[1])  # Assuming data shape: (n_channels, n_times)

# Generate plots
fig, axes = plt.subplots(3, 1, figsize=(10, 18))
colors = {"Visual": "blue", "EMS": "green", "Vibro": "orange"}

for ax, data_type in zip(axes, ["normal", "conflict", "difference"]):
    for session, color in colors.items():
        avg_normal_channel = avg_data[session]["normal"][channel_idx, :]
        avg_conflict_channel = avg_data[session]["conflict"][channel_idx, :]
        
        if data_type == "normal":
            ax.plot(times, avg_normal_channel * 1e6, label=f'{session} ({channel})', color=color)
        elif data_type == "conflict":
            ax.plot(times, avg_conflict_channel * 1e6, label=f'{session} ({channel})', color=color)
        elif data_type == "difference":
            erp_difference = avg_conflict_channel - avg_normal_channel
            ax.plot(times, erp_difference * 1e6, label=f'{session} ({channel})', color=color, linestyle='--')
    
    ax.axvspan(0.1, 0.3, color='gray', alpha=0.2, label='Peak Search Window')
    ax.axhline(0, color='black', linestyle='--')
    ax.set_xlabel("Time (s)")
    ax.set_ylabel("Amplitude (µV)")
    ax.legend()
    ax.set_title(f"ERP Analysis - {data_type.capitalize()}")

plt.tight_layout()
plt.show()


# all_normal = []
# all_conflict = []


# for subject in subjects:
   
#     if sessions is not None:
#         for session in sessions:
#             try:
#                 normal_data, conflict_data = process_subject(subject, session, bids_root)
#                 print(f"Shape of normal_data for subject {subject}, session {session}: {normal_data.shape}")
#                 print(f"Shape of conflict_data for subject {subject}, session {session}: {conflict_data.shape}")
#                 all_normal.append(normal_data)
#                 all_conflict.append(conflict_data)
#             except FileNotFoundError:
#                 print(f"File not found for subject {subject}, session {session}. Skipping this session.")
#                 continue  
#     else:
#         print(f"Session list is empty or None for subject {subject}. Skipping subject.")



# print(f"Shape of all_normal: {[data.shape for data in all_normal]}")
# print(f"Shape of all_conflict: {[data.shape for data in all_conflict]}")


# avg_normal = np.mean(all_normal, axis=0)
# avg_conflict = np.mean(all_conflict, axis=0)

# # Define the target channel
# channel = 'Cz'


# raw_example = read_raw_bids(BIDSPath(
#     subject=subjects[0], session=sessions[0], task="PredictionError", suffix="eeg", extension=".vhdr", root=bids_root
# ))
# channel_idx = raw_example.info['ch_names'].index(channel)


# avg_normal_channel = avg_normal[channel_idx, :]  # Shape: (n_times,)
# avg_conflict_channel = avg_conflict[channel_idx, :]  # Shape: (n_times,)


# erp_difference = avg_conflict_channel - avg_normal_channel


# times = np.linspace(-0.3, 0.7, avg_normal_channel.shape[0]) 

# fig, ax = plt.subplots(figsize=(10, 6))

# ax.plot(times, avg_normal_channel * 1e6, label=f'Match ({channel})', color='blue')
# ax.plot(times, avg_conflict_channel * 1e6, label=f'Mismatch ({channel})', color='red')
# ax.plot(times, erp_difference * 1e6, label=f'Match - Mismatch ({channel})', color='purple', linestyle='--')


# ax.axvspan(0.1, 0.3, color='gray', alpha=0.2, label='Peak Search Window')


# ax.axhline(0, color='black', linestyle='--')
# ax.set_title(f"ERP Analysis at {channel}: Match, Mismatch, and Difference")
# ax.set_xlabel("Time (s)")
# ax.set_ylabel("Amplitude (µV)")
# ax.legend()

# plt.tight_layout()
# plt.show()
# Out:
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.9492652;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.066743;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.9492652;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.066743;emsCurrent:7;emsWidth:200;pulseCount:12
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1005393
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1005393
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:55;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.03162
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.208562;trial_nr:55;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.03162;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:1.208562;trial_nr:55;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.03162;emsCurrent:7;emsWidth:200;pulseCount:12
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.103616
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.103616
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:56;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.208763
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6253939;trial_nr:56;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.208763;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6253939;trial_nr:56;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.208763;emsCurrent:7;emsWidth:200;pulseCount:12
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.10083
# ...
# Processing annotation: box:spawned;condition:visual;trial_nr:274;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.77422
# Processing annotation: box:touched;condition:visual;reaction_time:0.8603909;trial_nr:274;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.77422
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:275;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.887946
# Processing annotation: box:touched;condition:visual;reaction_time:0.8261571;trial_nr:275;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.887946
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:276;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.763304
# Processing annotation: box:touched;condition:visual;reaction_time:0.7709906;trial_nr:276;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.763304
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:277;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.99297
# Processing annotation: box:touched;condition:visual;reaction_time:0.636646;trial_nr:277;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.99297
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:278;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.130128
# Processing annotation: box:touched;condition:visual;reaction_time:0.781435;trial_nr:278;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.130128
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:279;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.186454
# Processing annotation: box:touched;condition:visual;reaction_time:0.8486409;trial_nr:279;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.186454
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:280;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.930584
# Processing annotation: box:touched;condition:visual;reaction_time:0.5813143;trial_nr:280;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.930584
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:281;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.370547
# Processing annotation: box:touched;condition:visual;reaction_time:0.7377169;trial_nr:281;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.370547
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:282;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.452353
# Processing annotation: box:touched;condition:visual;reaction_time:0.6484792;trial_nr:282;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.452353
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:283;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.26435
# Processing annotation: box:touched;condition:visual;reaction_time:0.8609533;trial_nr:283;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.26435
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:284;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.30257
# Processing annotation: box:touched;condition:visual;reaction_time:0.7485476;trial_nr:284;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.30257
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:285;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.363259
# Processing annotation: box:touched;condition:visual;reaction_time:0.8378396;trial_nr:285;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.363259
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:286;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.13991
# Processing annotation: box:touched;condition:visual;reaction_time:0.7922735;trial_nr:286;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.13991
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:287;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.21397
# Processing annotation: box:touched;condition:visual;reaction_time:0.547543;trial_nr:287;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.21397
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:288;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.918954
# Processing annotation: box:touched;condition:visual;reaction_time:0.7714269;trial_nr:288;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.918954
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:289;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.339074
# Processing annotation: box:touched;condition:visual;reaction_time:0.8041265;trial_nr:289;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.339074
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:290;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.464147
# Processing annotation: box:touched;condition:visual;reaction_time:0.8380919;trial_nr:290;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.464147
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:291;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.05996
# Processing annotation: box:touched;condition:visual;reaction_time:0.5694046;trial_nr:291;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.05996
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:292;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.093237
# Processing annotation: box:touched;condition:visual;reaction_time:0.9613366;trial_nr:292;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.093237
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:293;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.087567
# Processing annotation: box:touched;condition:visual;reaction_time:0.9058518;trial_nr:293;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.087567
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:294;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.747533
# Processing annotation: box:touched;condition:visual;reaction_time:0.9491682;trial_nr:294;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.747533
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:295;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.313653
# Processing annotation: box:touched;condition:visual;reaction_time:0.7927942;trial_nr:295;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.313653
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:296;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.856257
# Processing annotation: box:touched;condition:visual;reaction_time:0.8826456;trial_nr:296;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.856257
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:297;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.712451
# Processing annotation: box:touched;condition:visual;reaction_time:0.5919394;trial_nr:297;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.712451
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:298;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.207658
# Processing annotation: box:touched;condition:visual;reaction_time:0.8268895;trial_nr:298;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.207658
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:299;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.912789
# Processing annotation: box:touched;condition:visual;reaction_time:0.7486584;trial_nr:299;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.912789
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:300;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.519756
# Processing annotation: box:touched;condition:visual;reaction_time:0.6254356;trial_nr:300;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.519756
# Processing annotation: ipq_question_nr_1_answer:4
# Skipping irrelevant annotation: ipq_question_nr_1_answer:4
# Processing annotation: ipq_question_nr_2_answer:6
# Skipping irrelevant annotation: ipq_question_nr_2_answer:6
# Processing annotation: ipq_question_nr_3_answer:4
# Skipping irrelevant annotation: ipq_question_nr_3_answer:4
# Processing annotation: ipq_question_nr_4_answer:4
# Skipping irrelevant annotation: ipq_question_nr_4_answer:4
# Processing annotation: block:end;currentBlockNr:3;condition:visual;training:false
# Skipping irrelevant annotation: block:end;currentBlockNr:3;condition:visual;training:false
# Not setting metadata
# 600 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 600 events and 251 original time points ...
# /var/folders/g2/2m2f5nv928vg7nqvgz7glpjm0000gn/T/ipykernel_2725/380055758.py:26: RuntimeWarning: Not setting position of 1 eog channel found in montage:
# ['Fp2']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw_referenced = raw_filtered.set_eeg_reference(ref_channels="average").set_montage("standard_1020")  # Re-reference
# 0 bad epochs dropped
# Total epochs: 600
# Fitting ICA to data using 63 channels (please be patient, this may take a while)
# /var/folders/g2/2m2f5nv928vg7nqvgz7glpjm0000gn/T/ipykernel_2725/380055758.py:63: RuntimeWarning: The epochs you passed to ICA.fit() were baseline-corrected. However, we suggest to fit ICA only on data that has been high-pass filtered, but NOT baseline-corrected.
#   ica.fit(clean_epochs)
# Selecting by number: 10 components
# Fitting ICA took 13.0s.
# <MNEFigure size 975x496 with 10 Axes>
# /var/folders/g2/2m2f5nv928vg7nqvgz7glpjm0000gn/T/ipykernel_2725/380055758.py:70: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   labels = label_components(raw_referenced, ica, method='iclabel')
# /var/folders/g2/2m2f5nv928vg7nqvgz7glpjm0000gn/T/ipykernel_2725/380055758.py:70: RuntimeWarning: The provided ICA instance was fitted with a 'picard' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   labels = label_components(raw_referenced, ica, method='iclabel')
# ICLabel Results:
# Component 0: other (Probability: 0.73)
# Component 1: other (Probability: 0.63)
# Component 2: eye blink (Probability: 1.00)
# Component 3: other (Probability: 0.47)
# Component 4: other (Probability: 0.40)
# Component 5: muscle artifact (Probability: 0.60)
# Component 6: brain (Probability: 0.90)
# Component 7: other (Probability: 0.48)
# Component 8: other (Probability: 0.37)
# Component 9: other (Probability: 0.68)
# Applying ICA to Raw instance
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 63 PCA components
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.2 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.20
# - Lower transition bandwidth: 0.20 Hz (-6 dB cutoff frequency: 0.10 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 4125 samples (16.500 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Channel Fz: Negativity peak at 0.100 s with amplitude 0.000 µV
# Channel Cz: Negativity peak at 0.188 s with amplitude -0.000 µV
# Channel Fp1: Negativity peak at 0.100 s with amplitude 0.000 µV
# Channel FC1: Negativity peak at 0.280 s with amplitude -0.000 µV
# Channel FC2: Negativity peak at 0.280 s with amplitude -0.000 µV
# Match trials: 450, Mismatch trials: 150
# Shape of normal_data for subject 03, session Visual: (63, 251)
# Shape of conflict_data for subject 03, session Visual: (63, 251)
# Extracting parameters from /Users/sergeiukhov/Documents/EEGNEW/sub-02/ses-EMS/eeg/sub-02_ses-EMS_task-PredictionError_eeg.vhdr...
# Setting channel info structure...
# Reading events from /Users/sergeiukhov/Documents/EEGNEW/sub-02/ses-EMS/eeg/sub-02_ses-EMS_task-PredictionError_events.tsv.
# Reading channel info from /Users/sergeiukhov/Documents/EEGNEW/sub-02/ses-EMS/eeg/sub-02_ses-EMS_task-PredictionError_channels.tsv.

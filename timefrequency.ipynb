# %%
import os
import numpy as np
import mne
import matplotlib.pyplot as plt
from mne_bids import BIDSPath, read_raw_bids
from mne_icalabel import label_components
from mne.preprocessing import ICA

event_id = {
    'normal': 1,   
    'conflict': 2  
}

'''I have repurposed the below function to output epochs_match and epoch_mismatch variables that we need for time-freq analysis whilst preserving all the preprocessing steps.'''


def process_subject(subject_id, session, bids_root):
    
    # Define file paths
    bids_path = BIDSPath(
        subject=subject_id, session=session, task="PredictionError", suffix="eeg", extension=".vhdr", root=bids_root
    )
    
    # Load raw data
    raw = read_raw_bids(bids_path)

    # Preprocessing steps
    raw.annotations.onset -= 0.063  # Adjust for EEG setup delay
    raw_resampled = raw.copy().resample(sfreq=250, npad="auto")  # Resample
    raw_filtered = raw_resampled.filter(l_freq=1.0, h_freq=124.0).notch_filter(freqs=50)  # Bandpass + Notch filter
    raw_referenced = raw_filtered.set_eeg_reference(ref_channels="average").set_montage("standard_1020")  # Re-reference
    
    # Step 5: Extract events based on annotations
    events = []
    for annot in raw_referenced.annotations:
        print(f"Processing annotation: {annot['description']}")
        if 'normal_or_conflict:normal' in annot['description']:
            events.append([int(annot['onset'] * raw_referenced.info['sfreq']), 0, event_id['normal']])
        elif 'normal_or_conflict:conflict' in annot['description']:
            events.append([int(annot['onset'] * raw_referenced.info['sfreq']), 0, event_id['conflict']])
        else:
            print("Skipping irrelevant annotation:", annot['description'])
    events = np.array(events, dtype=int)

    # Extract epochs
    epochs = mne.Epochs(
        raw_referenced, events, event_id=event_id, tmin=-0.3, tmax=0.7,
        baseline=(-0.3, 0), preload=True, event_repeated='merge'
    )
    print(f"Total epochs: {len(epochs)}")

    # Compute Mean Absolute Amplitude for Each Epoch
    epoch_data = epochs.get_data()  # Shape: (n_epochs, n_channels, n_times)
    mean_amplitudes = np.mean(np.abs(epoch_data), axis=(1, 2))  # Mean over channels and time

    # Rank Epochs by Mean Amplitude
    ranked_indices = np.argsort(mean_amplitudes)  

    # Keep 85% of the Cleanest Epochs
    percentage = 85
    n_epochs_to_keep = int(len(epochs) * (percentage / 100))
    selected_indices = ranked_indices[:n_epochs_to_keep]  # Select top 85% clean epochs

    # Create Clean Epochs and Apply ICA
    clean_epochs = epochs[selected_indices]

    ica = ICA(n_components=10, method='picard', random_state=42, max_iter=5000)
    ica.fit(clean_epochs)

    ica.plot_components()

    from mne_icalabel import label_components

    # Step 6: Use ICLabel for automatic component classification
    labels = label_components(raw_referenced, ica, method='iclabel')

    print("ICLabel Results:")
    for idx, (label, prob) in enumerate(zip(labels['labels'], labels['y_pred_proba'])):
        print(f"Component {idx}: {label} (Probability: {prob:.2f})")

    # Automatically mark bad components for exclusion
    bad_ics = [idx for idx, label in enumerate(labels['labels'])
            if label in ('eye blink', 'muscle artifact', 'line_noise')]

    ica.exclude = bad_ics  # Mark components for exclusion

    ica.apply(raw_referenced)

    raw_referenced.set_meas_date(None)

    #raw_referenced.save(f"cleaned_data_{subject_id}_{session}.fif", overwrite=True)

    # Step 7: Filter ERP data with 0.2 Hz high-pass and 35 Hz low-pass
    raw_referenced = raw_referenced.copy().filter(l_freq=0.2, h_freq=35.0)

    # Step 9: Reject 10% of the noisiest epochs based on signal amplitude
    epoch_data = epochs.get_data()  # Shape: (n_epochs, n_channels, n_times)
    mean_amplitudes = np.mean(np.abs(epoch_data), axis=(1, 2))  # Compute mean amplitude for each epoch
    threshold = np.percentile(mean_amplitudes, 90)  # Top 10% noisy epochs
    clean_epochs = epochs[mean_amplitudes < threshold]

    # Step 10: Focus analyses on selected electrodes 
    frontal_channels = ['Fz', 'Cz', 'Fp1', 'FC1', 'FC2']
    clean_epochs.pick_channels(frontal_channels)

    # Step 11: Extract ERP negativity peaks (minimum peak) in the 100–300 ms time window
    time_window = (0.1, 0.3)  # 100–300 ms
    negativity_peaks = {}

    for ch_name in frontal_channels:
        channel_idx = clean_epochs.ch_names.index(ch_name)
        erp_data = clean_epochs.average().data[channel_idx]
        times = clean_epochs.times

        # Extract the data within the time window
        mask = (times >= time_window[0]) & (times <= time_window[1])
        time_window_data = erp_data[mask]
        time_window_times = times[mask]

        # Find the minimum (negative) peak
        peak_idx = np.argmin(time_window_data)
        peak_time = time_window_times[peak_idx]
        peak_amplitude = time_window_data[peak_idx]

        negativity_peaks[ch_name] = (peak_time, peak_amplitude)
        print(f"Channel {ch_name}: Negativity peak at {peak_time:.3f} s with amplitude {peak_amplitude:.3f} µV")


    epochs_match = epochs['normal']
    epochs_mismatch = epochs['conflict']
    print(f"Match trials: {len(epochs_match)}, Mismatch trials: {len(epochs_mismatch)}")


    # erp_normal = epochs_match.average()
    # erp_conflict = epochs_mismatch.average()

    # return erp_normal.data, erp_conflict.data
    return epochs_match, epochs_mismatch



'''Below we are plotting the results for only one subject. What needs to be done is the iteration across all subjects.'''

bids_root = "/Users/sergeiukhov/Documents/EEGNEW"
# subjects = ["02", "03","06","07","08","11","12","13","14","15","16"]

subjects = "08"
sessions = "EMS"  #just this one session for testing

channel = 'Fz'

epochs_match, epochs_mismatch = process_subject(subjects, sessions, bids_root)

freqs = np.arange(1,124,1)  # Same frequency as in the preprocessing part
n_cycles = freqs / 2  # Adjusting wavelet cycles per frequency

# Time-Frequency Representation
tfr_match = mne.time_frequency.tfr_morlet(
    epochs_match, freqs=freqs, n_cycles=n_cycles, use_fft=True, return_itc=False, decim=3, n_jobs=1
)

tfr_mismatch = mne.time_frequency.tfr_morlet(
    epochs_mismatch, freqs=freqs, n_cycles=n_cycles, use_fft=True, return_itc=False, decim=3, n_jobs=1
)

tfr_match.plot(picks='Fz', title="Time-Frequency (Match)")
tfr_mismatch.plot(picks='Fz', title="Time-Frequency (Mismatch)" )


'''Plotting's a bit off, it plots them individually but when placed together, one is empty :/'''

ch_idx = epochs_match.ch_names.index(channel)
ch_idx1 = epochs_mismatch.ch_names.index(channel)

fig, axes = plt.subplots(1, 2, figsize=(14, 8))

# Plotting for match trials
tfr_match.plot([ch_idx], baseline=(-0.3, 0), mode="logratio", title="TFR - Match", axes=axes[0])

# Plotting for mismatch trials
tfr_mismatch.plot([ch_idx1], baseline=(-0.3, 0), mode="logratio", title="TFR - Mismatch", axes=axes[1])

plt.show()
# Out:
# Extracting parameters from /Users/sergeiukhov/Documents/EEGNEW/sub-08/ses-EMS/eeg/sub-08_ses-EMS_task-PredictionError_eeg.vhdr...
# Setting channel info structure...
# Reading events from /Users/sergeiukhov/Documents/EEGNEW/sub-08/ses-EMS/eeg/sub-08_ses-EMS_task-PredictionError_events.tsv.
# Reading channel info from /Users/sergeiukhov/Documents/EEGNEW/sub-08/ses-EMS/eeg/sub-08_ses-EMS_task-PredictionError_channels.tsv.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1.2e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 124.00 Hz
# - Upper transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 124.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Processing annotation: block:start;currentBlockNr:1;condition:vibro;training:false
# Skipping irrelevant annotation: block:start;currentBlockNr:1;condition:vibro;training:false
# Processing annotation: box:spawned;condition:vibro;trial_nr:1;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.560685
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8949935;trial_nr:1;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.560685;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8949935;trial_nr:1;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.560685;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1039482
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1039482
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:2;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.000268
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7596159;trial_nr:2;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.000268;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7596159;trial_nr:2;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.000268;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.100589
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.100589
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:3;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.613245
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8035302;trial_nr:3;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.613245;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8035302;trial_nr:3;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.613245;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1007076
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1007076
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:4;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.12971
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7258968;trial_nr:4;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.12971;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7258968;trial_nr:4;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.12971;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1001517
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1001517
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:5;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.333669
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7261431;trial_nr:5;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.333669;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7261431;trial_nr:5;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.333669;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1044429
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1044429
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:6;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.310617
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.4822092;trial_nr:6;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.310617;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.4822092;trial_nr:6;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.310617;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1097379
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1097379
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:7;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.510526
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.615026;trial_nr:7;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.510526;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.615026;trial_nr:7;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.510526;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1008265
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1008265
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:8;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.951481
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.569334;trial_nr:8;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.951481;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.569334;trial_nr:8;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.951481;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1002449
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1002449
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:9;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.780849
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6917799;trial_nr:9;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.780849;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6917799;trial_nr:9;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.780849;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1016399
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1016399
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:10;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.26556
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7814789;trial_nr:10;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.26556;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7814789;trial_nr:10;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.26556;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1009707
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1009707
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:11;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.192854
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5357618;trial_nr:11;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.192854;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5357618;trial_nr:11;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.192854;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1003255
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1003255
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:12;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.152219
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6372447;trial_nr:12;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.152219;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6372447;trial_nr:12;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.152219;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1115868
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1115868
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:13;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.033986
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6920767;trial_nr:13;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.033986;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6920767;trial_nr:13;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.033986;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1005306
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1005306
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:14;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.294004
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6378365;trial_nr:14;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.294004;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6378365;trial_nr:14;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.294004;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1104913
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1104913
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:15;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.188209
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6819878;trial_nr:15;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.188209;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6819878;trial_nr:15;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.188209;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.10083
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.10083
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:16;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.113243
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5359211;trial_nr:16;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.113243;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5359211;trial_nr:16;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.113243;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1016988
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1016988
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:17;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.455892
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6813428;trial_nr:17;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.455892;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6813428;trial_nr:17;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.455892;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.103998
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.103998
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:18;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.717467
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6696942;trial_nr:18;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.717467;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6696942;trial_nr:18;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.717467;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1011947
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1011947
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:19;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.365835
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7485321;trial_nr:19;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.365835;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7485321;trial_nr:19;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.365835;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004895
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004895
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:20;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.147217
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5590396;trial_nr:20;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.147217;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5590396;trial_nr:20;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.147217;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1003228
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1003228
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:21;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.658153
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7373662;trial_nr:21;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.658153;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7373662;trial_nr:21;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.658153;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004373
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004373
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:22;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.070554
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6477051;trial_nr:22;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.070554;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6477051;trial_nr:22;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.070554;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1001967
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1001967
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:23;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.16733
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5700598;trial_nr:23;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.16733;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5700598;trial_nr:23;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.16733;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1110708
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1110708
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:24;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.488887
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.152371;trial_nr:24;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.488887;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:1.152371;trial_nr:24;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.488887;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.10234
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.10234
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:25;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.998581
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6593549;trial_nr:25;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.998581;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6593549;trial_nr:25;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.998581;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1003042
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1003042
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:26;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.478037
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5139341;trial_nr:26;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.478037;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5139341;trial_nr:26;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.478037;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.101135
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.101135
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:27;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.776846
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6364038;trial_nr:27;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.776846;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6364038;trial_nr:27;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.776846;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.101971
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.101971
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:28;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.019563
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5698123;trial_nr:28;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.019563;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5698123;trial_nr:28;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.019563;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1010769
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1010769
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:29;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.066398
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6825895;trial_nr:29;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.066398;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6825895;trial_nr:29;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.066398;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1120198
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1120198
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:30;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.54057
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8933032;trial_nr:30;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.54057;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8933032;trial_nr:30;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.54057;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1014937
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1014937
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:31;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.023214
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5586634;trial_nr:31;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.023214;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5586634;trial_nr:31;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.023214;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1008747
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1008747
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:32;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.583797
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7486663;trial_nr:32;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.583797;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7486663;trial_nr:32;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.583797;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004085
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004085
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:33;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.410685
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7484047;trial_nr:33;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.410685;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7484047;trial_nr:33;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.410685;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1013503
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1013503
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:34;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.651316
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7148116;trial_nr:34;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.651316;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7148116;trial_nr:34;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.651316;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.100721
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.100721
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:35;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.739588
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8378041;trial_nr:35;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.739588;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8378041;trial_nr:35;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.739588;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.100461
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.100461
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:36;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.644112
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5811689;trial_nr:36;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.644112;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5811689;trial_nr:36;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.644112;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1030436
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1030436
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:37;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.896152
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7592406;trial_nr:37;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.896152;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7592406;trial_nr:37;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.896152;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1002216
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1002216
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:38;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.914783
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6931353;trial_nr:38;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.914783;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6931353;trial_nr:38;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.914783;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1013843
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1013843
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:39;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.781482
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.738435;trial_nr:39;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.781482;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.738435;trial_nr:39;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.781482;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1022791
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1022791
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:40;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.558555
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6140153;trial_nr:40;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.558555;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6140153;trial_nr:40;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.558555;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004409
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004409
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:41;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.279436
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6926575;trial_nr:41;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.279436;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6926575;trial_nr:41;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.279436;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1018457
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1018457
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:42;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.939679
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7032902;trial_nr:42;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.939679;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7032902;trial_nr:42;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.939679;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.100706
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.100706
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:43;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.961614
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6806743;trial_nr:43;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.961614;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6806743;trial_nr:43;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.961614;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004362
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004362
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:44;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.345825
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6587081;trial_nr:44;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.345825;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6587081;trial_nr:44;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.345825;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1005238
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1005238
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:45;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.606649
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7485139;trial_nr:45;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.606649;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7485139;trial_nr:45;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.606649;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1015885
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1015885
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:46;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.544528
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5918579;trial_nr:46;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.544528;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5918579;trial_nr:46;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.544528;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1000032
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1000032
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:47;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.883768
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6590664;trial_nr:47;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.883768;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6590664;trial_nr:47;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.883768;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1000909
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1000909
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:48;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.671604
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5136847;trial_nr:48;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.671604;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5136847;trial_nr:48;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.671604;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1015016
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1015016
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:49;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.158622
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7143893;trial_nr:49;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.158622;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7143893;trial_nr:49;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.158622;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1008107
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1008107
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:50;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.224302
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6591215;trial_nr:50;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.224302;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6591215;trial_nr:50;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.224302;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004148
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004148
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:51;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.307464
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5581269;trial_nr:51;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.307464;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5581269;trial_nr:51;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.307464;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1032292
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1032292
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:52;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.05208
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8599653;trial_nr:52;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.05208;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8599653;trial_nr:52;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.05208;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004958
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004958
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:53;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.412458
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6933992;trial_nr:53;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.412458;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6933992;trial_nr:53;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.412458;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1003994
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1003994
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.40072
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7147508;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.40072;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7147508;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.40072;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1111775
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1111775
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:55;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.637555
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8152101;trial_nr:55;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.637555;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8152101;trial_nr:55;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.637555;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1007878
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1007878
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:56;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.408979
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5812135;trial_nr:56;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.408979;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5812135;trial_nr:56;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.408979;emsCurrent:12;emsWidth:200;pulseCount:14
# ...
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1007692
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:91;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.780118
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5587699;trial_nr:91;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.780118;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5587699;trial_nr:91;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.780118;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1001343
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1001343
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:92;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.757778
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7149026;trial_nr:92;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.757778;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7149026;trial_nr:92;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.757778;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1016075
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1016075
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:93;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.403828
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8504632;trial_nr:93;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.403828;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8504632;trial_nr:93;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.403828;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1144822
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1144822
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:94;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.177931
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7933626;trial_nr:94;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.177931;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7933626;trial_nr:94;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.177931;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004701
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004701
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:95;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.612456
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8051388;trial_nr:95;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.612456;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8051388;trial_nr:95;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.612456;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1027761
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1027761
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:96;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.629352
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5922372;trial_nr:96;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.629352;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5922372;trial_nr:96;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.629352;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1013029
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1013029
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:97;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.074071
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7933149;trial_nr:97;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.074071;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7933149;trial_nr:97;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.074071;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1007514
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1007514
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:98;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.692374
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.893503;trial_nr:98;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.692374;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.893503;trial_nr:98;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.692374;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1045558
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1045558
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:99;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.392253
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7363732;trial_nr:99;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.392253;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7363732;trial_nr:99;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.392253;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004915
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004915
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:100;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.157476
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5483274;trial_nr:100;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.157476;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5483274;trial_nr:100;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.157476;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.111044
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.111044
# Processing annotation: block:start;currentBlockNr:1;condition:vibro;training:true
# Skipping irrelevant annotation: block:start;currentBlockNr:1;condition:vibro;training:true
# Processing annotation: box:spawned;condition:vibro;trial_nr:1;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.124506
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.2173;trial_nr:1;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.124506;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:1.2173;trial_nr:1;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.124506;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1005732
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1005732
# Processing annotation: block:start;currentBlockNr:2;condition:vibro;training:true
# Skipping irrelevant annotation: block:start;currentBlockNr:2;condition:vibro;training:true
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:101;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.954353
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.183851;trial_nr:101;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.954353;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:1.183851;trial_nr:101;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.954353;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1009426
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1009426
# Processing annotation: block:start;currentBlockNr:3;condition:vibro;training:true
# Skipping irrelevant annotation: block:start;currentBlockNr:3;condition:vibro;training:true
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:201;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.008163
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8159795;trial_nr:201;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.008163;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8159795;trial_nr:201;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.008163;emsCurrent:12;emsWidth:200;pulseCount:14
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1006455
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1006455
# Processing annotation: ipq_question_nr_1_answer:5
# Skipping irrelevant annotation: ipq_question_nr_1_answer:5
# Processing annotation: ipq_question_nr_2_answer:5
# Skipping irrelevant annotation: ipq_question_nr_2_answer:5
# Processing annotation: ipq_question_nr_3_answer:3
# Skipping irrelevant annotation: ipq_question_nr_3_answer:3
# Processing annotation: ipq_question_nr_4_answer:3
# Skipping irrelevant annotation: ipq_question_nr_4_answer:3
# Processing annotation: block:end;currentBlockNr:3;condition:vibro;training:true
# Skipping irrelevant annotation: block:end;currentBlockNr:3;condition:vibro;training:true
# Not setting metadata
# 309 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 309 events and 251 original time points ...
# 0 bad epochs dropped
# Total epochs: 309
# Fitting ICA to data using 63 channels (please be patient, this may take a while)
# /var/folders/g2/2m2f5nv928vg7nqvgz7glpjm0000gn/T/ipykernel_28004/4145061045.py:31: RuntimeWarning: Not setting position of 1 eog channel found in montage:
# ['Fp2']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw_referenced = raw_filtered.set_eeg_reference(ref_channels="average").set_montage("standard_1020")  # Re-reference
# /var/folders/g2/2m2f5nv928vg7nqvgz7glpjm0000gn/T/ipykernel_28004/4145061045.py:68: RuntimeWarning: The epochs you passed to ICA.fit() were baseline-corrected. However, we suggest to fit ICA only on data that has been high-pass filtered, but NOT baseline-corrected.
#   ica.fit(clean_epochs)
# Selecting by number: 10 components
# Fitting ICA took 4.8s.
# <MNEFigure size 975x496 with 10 Axes>
# /var/folders/g2/2m2f5nv928vg7nqvgz7glpjm0000gn/T/ipykernel_28004/4145061045.py:75: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   labels = label_components(raw_referenced, ica, method='iclabel')
# /var/folders/g2/2m2f5nv928vg7nqvgz7glpjm0000gn/T/ipykernel_28004/4145061045.py:75: RuntimeWarning: The provided ICA instance was fitted with a 'picard' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   labels = label_components(raw_referenced, ica, method='iclabel')
# ICLabel Results:
# Component 0: eye blink (Probability: 1.00)
# Component 1: eye blink (Probability: 1.00)
# Component 2: brain (Probability: 1.00)
# Component 3: brain (Probability: 1.00)
# Component 4: brain (Probability: 0.99)
# Component 5: brain (Probability: 0.85)
# Component 6: muscle artifact (Probability: 1.00)
# Component 7: brain (Probability: 0.52)
# Component 8: eye blink (Probability: 0.38)
# Component 9: muscle artifact (Probability: 1.00)
# Applying ICA to Raw instance
#     Transforming to ICA space (10 components)
#     Zeroing out 5 ICA components
#     Projecting back using 63 PCA components
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.2 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.20
# - Lower transition bandwidth: 0.20 Hz (-6 dB cutoff frequency: 0.10 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 4125 samples (16.500 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Channel Fz: Negativity peak at 0.240 s with amplitude -0.000 µV
# Channel Cz: Negativity peak at 0.128 s with amplitude -0.000 µV
# Channel Fp1: Negativity peak at 0.240 s with amplitude 0.000 µV
# Channel FC1: Negativity peak at 0.240 s with amplitude -0.000 µV
# Channel FC2: Negativity peak at 0.128 s with amplitude -0.000 µV
# Match trials: 234, Mismatch trials: 75
# NOTE: tfr_morlet() is a legacy function. New code should use .compute_tfr(method="morlet").
# NOTE: tfr_morlet() is a legacy function. New code should use .compute_tfr(method="morlet").
# No baseline correction applied
# No baseline correction applied
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)

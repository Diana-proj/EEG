# %%
import os
import numpy as np
import mne
import matplotlib.pyplot as plt
from mne_bids import BIDSPath, read_raw_bids
from mne_icalabel import label_components
from mne.preprocessing import ICA

event_id = {
    'normal': 1,   
    'conflict': 2  
}

'''I have repurposed the below function to output epochs_match and epoch_mismatch variables that we need for time-freq analysis whilst preserving all the preprocessing steps.'''


def process_subject(subject_id, session, bids_root):
    
    # Define file paths
    bids_path = BIDSPath(
        subject=subject_id, session=session, task="PredictionError", suffix="eeg", extension=".vhdr", root=bids_root
    )
    
    # Load raw data
    raw = read_raw_bids(bids_path)

    # Preprocessing steps
    raw.annotations.onset -= 0.063  # Adjust for EEG setup delay
    raw_resampled = raw.copy().resample(sfreq=250, npad="auto")  # Resample
    raw_filtered = raw_resampled.filter(l_freq=1.0, h_freq=124.0).notch_filter(freqs=50)  # Bandpass + Notch filter
    raw_referenced = raw_filtered.set_eeg_reference(ref_channels="average").set_montage("standard_1020")  # Re-reference
    
    # Step 5: Extract events based on annotations
    events = []
    for annot in raw_referenced.annotations:
        print(f"Processing annotation: {annot['description']}")
        if 'normal_or_conflict:normal' in annot['description']:
            events.append([int(annot['onset'] * raw_referenced.info['sfreq']), 0, event_id['normal']])
        elif 'normal_or_conflict:conflict' in annot['description']:
            events.append([int(annot['onset'] * raw_referenced.info['sfreq']), 0, event_id['conflict']])
        else:
            print("Skipping irrelevant annotation:", annot['description'])
    events = np.array(events, dtype=int)

    # Extract epochs
    epochs = mne.Epochs(
        raw_referenced, events, event_id=event_id, tmin=-0.3, tmax=0.7,
        baseline=(-0.3, 0), preload=True, event_repeated='merge'
    )
    print(f"Total epochs: {len(epochs)}")

    # Compute Mean Absolute Amplitude for Each Epoch
    epoch_data = epochs.get_data()  # Shape: (n_epochs, n_channels, n_times)
    mean_amplitudes = np.mean(np.abs(epoch_data), axis=(1, 2))  # Mean over channels and time

    # Rank Epochs by Mean Amplitude
    ranked_indices = np.argsort(mean_amplitudes)  

    # Keep 85% of the Cleanest Epochs
    percentage = 85
    n_epochs_to_keep = int(len(epochs) * (percentage / 100))
    selected_indices = ranked_indices[:n_epochs_to_keep]  # Select top 85% clean epochs

    # Create Clean Epochs and Apply ICA
    clean_epochs = epochs[selected_indices]

    ica = ICA(n_components=10, method='picard', random_state=42, max_iter=5000)
    ica.fit(clean_epochs)

    ica.plot_components()

    from mne_icalabel import label_components

    # Step 6: Use ICLabel for automatic component classification
    labels = label_components(raw_referenced, ica, method='iclabel')

    print("ICLabel Results:")
    for idx, (label, prob) in enumerate(zip(labels['labels'], labels['y_pred_proba'])):
        print(f"Component {idx}: {label} (Probability: {prob:.2f})")

    # Automatically mark bad components for exclusion
    bad_ics = [idx for idx, label in enumerate(labels['labels'])
            if label in ('eye blink', 'muscle artifact', 'line_noise')]

    ica.exclude = bad_ics  # Mark components for exclusion

    ica.apply(raw_referenced)

    raw_referenced.set_meas_date(None)

    #raw_referenced.save(f"cleaned_data_{subject_id}_{session}.fif", overwrite=True)

    # Step 7: Filter ERP data with 0.2 Hz high-pass and 35 Hz low-pass
    raw_referenced = raw_referenced.copy().filter(l_freq=0.2, h_freq=35.0)

    # Step 9: Reject 10% of the noisiest epochs based on signal amplitude
    epoch_data = epochs.get_data()  # Shape: (n_epochs, n_channels, n_times)
    mean_amplitudes = np.mean(np.abs(epoch_data), axis=(1, 2))  # Compute mean amplitude for each epoch
    threshold = np.percentile(mean_amplitudes, 90)  # Top 10% noisy epochs
    clean_epochs = epochs[mean_amplitudes < threshold]

    # Step 10: Focus analyses on selected electrodes 
    frontal_channels = ['Fz', 'Cz', 'Fp1', 'FC1', 'FC2']
    clean_epochs.pick_channels(frontal_channels)

    # Step 11: Extract ERP negativity peaks (minimum peak) in the 100–300 ms time window
    time_window = (0.1, 0.3)  # 100–300 ms
    negativity_peaks = {}

    for ch_name in frontal_channels:
        channel_idx = clean_epochs.ch_names.index(ch_name)
        erp_data = clean_epochs.average().data[channel_idx]
        times = clean_epochs.times

        # Extract the data within the time window
        mask = (times >= time_window[0]) & (times <= time_window[1])
        time_window_data = erp_data[mask]
        time_window_times = times[mask]

        # Find the minimum (negative) peak
        peak_idx = np.argmin(time_window_data)
        peak_time = time_window_times[peak_idx]
        peak_amplitude = time_window_data[peak_idx]

        negativity_peaks[ch_name] = (peak_time, peak_amplitude)
        print(f"Channel {ch_name}: Negativity peak at {peak_time:.3f} s with amplitude {peak_amplitude:.3f} µV")


    epochs_match = epochs['normal']
    epochs_mismatch = epochs['conflict']
    print(f"Match trials: {len(epochs_match)}, Mismatch trials: {len(epochs_mismatch)}")


    # erp_normal = epochs_match.average()
    # erp_conflict = epochs_mismatch.average()

    # return erp_normal.data, erp_conflict.data
    return epochs_match, epochs_mismatch



'''Below we are plotting the results for only one subject. What needs to be done is the iteration across all subjects.'''

bids_root = "/home/st/st_us-053000/st_st190561/EEG"
subjects = ["02"]
#subjects = ["02", "03", "06", "07", "08", "11", "12", "13", "14", "15", "16"]

sessions = ["Visual", "EMS", "Vibro"]

channel = 'Fz'

# Initialize lists for storing TFR data
tfr_normal_visual, tfr_conflict_visual = [], []
tfr_normal_ems, tfr_conflict_ems = [], []
tfr_normal_vibro, tfr_conflict_vibro = [], []

for subject in subjects:
    for session in sessions:
        try:
            print(f"Processing Subject {subject}, Session {session}...")

            freqs = np.arange(1, 124, 1)
            n_cycles = freqs / 2

            epochs_match, epochs_mismatch = process_subject(subject, session, bids_root)


            tfr_match = mne.time_frequency.tfr_morlet(epochs_match, freqs=freqs, n_cycles=n_cycles,
                                                      use_fft=True, return_itc=False, decim=3, n_jobs=1)

            tfr_mismatch = mne.time_frequency.tfr_morlet(epochs_mismatch, freqs=freqs, n_cycles=n_cycles,
                                                         use_fft=True, return_itc=False, decim=3, n_jobs=1)


            if session == "Visual":
                tfr_conflict_visual.append(tfr_mismatch.data)
                tfr_normal_visual.append(tfr_match.data)
            elif session == "EMS":
                tfr_conflict_ems.append(tfr_mismatch.data)
                tfr_normal_ems.append(tfr_match.data)
            elif session == "Vibro":
                tfr_conflict_vibro.append(tfr_mismatch.data)
                tfr_normal_vibro.append(tfr_match.data)

        except FileNotFoundError:
            print(f"File not found for subject {subject}, session {session}. Skipping this session.")
            continue


avg_data = {
    "Visual": {
        "normal": np.mean(tfr_normal_visual, axis=0) if tfr_normal_visual else None,
        "conflict": np.mean(tfr_conflict_visual, axis=0) if tfr_conflict_visual else None,
    },
    "EMS": {
        "normal": np.mean(tfr_normal_ems, axis=0) if tfr_normal_ems else None,
        "conflict": np.mean(tfr_conflict_ems, axis=0) if tfr_conflict_ems else None,
    },
    "Vibro": {
        "normal": np.mean(tfr_normal_vibro, axis=0) if tfr_normal_vibro else None,
        "conflict": np.mean(tfr_conflict_vibro, axis=0) if tfr_conflict_vibro else None,
    },
}


tfr_match_avg = tfr_match.copy()
tfr_match_avg.data = avg_data["EMS"]["normal"]  # Change to the desired session

tfr_mismatch_avg = tfr_mismatch.copy()
tfr_mismatch_avg.data = avg_data["EMS"]["conflict"]


fig, axes = plt.subplots(1, 2, figsize=(14, 8))


im1 = axes[0].imshow(tfr_match_avg.data[epochs_match.ch_names.index(channel)], aspect='auto', 
                      origin='lower', extent=[epochs_match.times[0], epochs_match.times[-1], freqs[0], freqs[-1]])
axes[0].set_title("TFR - Match")
fig.colorbar(im1, ax=axes[0])

im2 = axes[1].imshow(tfr_mismatch_avg.data[epochs_mismatch.ch_names.index(channel)], aspect='auto',
                      origin='lower', extent=[epochs_mismatch.times[0], epochs_mismatch.times[-1], freqs[0], freqs[-1]])
axes[1].set_title("TFR - Mismatch")
fig.colorbar(im2, ax=axes[1])

plt.show()
# Out:
# Processing Subject 02, Session Visual...
# Extracting parameters from /home/st/st_us-053000/st_st190561/EEG/sub-02/ses-Visual/eeg/sub-02_ses-Visual_task-PredictionError_eeg.vhdr...
# Setting channel info structure...
# Reading events from /home/st/st_us-053000/st_st190561/EEG/sub-02/ses-Visual/eeg/sub-02_ses-Visual_task-PredictionError_events.tsv.
# Reading channel info from /home/st/st_us-053000/st_st190561/EEG/sub-02/ses-Visual/eeg/sub-02_ses-Visual_task-PredictionError_channels.tsv.
# /scratch/ipykernel_744126/2330229122.py:25: RuntimeWarning: Unable to map the following column(s) to to MNE:
# cap_size: 58
# block_1: Visual
# block_2: Visual + Vibro
# block_3: Visual + Vibro + EMS
#   raw = read_raw_bids(bids_path)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1.2e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 124.00 Hz
# - Upper transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 124.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Processing annotation: block:start;currentBlockNr:1;condition:visual;training:false
# Skipping irrelevant annotation: block:start;currentBlockNr:1;condition:visual;training:false
# Processing annotation: box:spawned;condition:visual;trial_nr:1;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.880659
# Processing annotation: box:touched;condition:visual;reaction_time:1.050021;trial_nr:1;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.880659
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:2;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.25513
# Processing annotation: box:touched;condition:visual;reaction_time:0.8605666;trial_nr:2;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.25513
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:3;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.638804
# Processing annotation: box:touched;condition:visual;reaction_time:0.8151078;trial_nr:3;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.638804
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:4;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.400802
# Processing annotation: box:touched;condition:visual;reaction_time:0.6474845;trial_nr:4;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.400802
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:5;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.395416
# Processing annotation: box:touched;condition:visual;reaction_time:0.6590152;trial_nr:5;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.395416
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:6;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.445164
# Processing annotation: box:touched;condition:visual;reaction_time:0.5471058;trial_nr:6;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.445164
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:7;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.378922
# Processing annotation: box:touched;condition:visual;reaction_time:0.8043504;trial_nr:7;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.378922
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:8;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.211167
# Processing annotation: box:touched;condition:visual;reaction_time:1.465045;trial_nr:8;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.211167
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:9;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.795674
# Processing annotation: box:touched;condition:visual;reaction_time:0.8265586;trial_nr:9;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.795674
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:10;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.487281
# Processing annotation: box:touched;condition:visual;reaction_time:0.5038533;trial_nr:10;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.487281
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:11;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.356528
# Processing annotation: box:touched;condition:visual;reaction_time:0.7692771;trial_nr:11;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.356528
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:12;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.727241
# Processing annotation: box:touched;condition:visual;reaction_time:0.8821034;trial_nr:12;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.727241
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:13;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.060536
# Processing annotation: box:touched;condition:visual;reaction_time:0.8384571;trial_nr:13;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.060536
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:14;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.672811
# Processing annotation: box:touched;condition:visual;reaction_time:1.01069;trial_nr:14;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.672811
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:15;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.167306
# Processing annotation: box:touched;condition:visual;reaction_time:0.5476794;trial_nr:15;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.167306
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:16;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.781906
# Processing annotation: box:touched;condition:visual;reaction_time:1.429915;trial_nr:16;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.781906
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:17;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.903384
# Processing annotation: box:touched;condition:visual;reaction_time:0.547662;trial_nr:17;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.903384
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:18;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.191931
# Processing annotation: box:touched;condition:visual;reaction_time:0.93801;trial_nr:18;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.191931
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:19;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.415128
# Processing annotation: box:touched;condition:visual;reaction_time:0.9480743;trial_nr:19;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.415128
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:20;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.071549
# Processing annotation: box:touched;condition:visual;reaction_time:0.6145554;trial_nr:20;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.071549
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:21;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.241962
# Processing annotation: box:touched;condition:visual;reaction_time:0.6927118;trial_nr:21;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.241962
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:22;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.290246
# Processing annotation: box:touched;condition:visual;reaction_time:0.7379029;trial_nr:22;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.290246
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:23;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.476493
# Processing annotation: box:touched;condition:visual;reaction_time:0.7153349;trial_nr:23;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.476493
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:24;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.866267
# Processing annotation: box:touched;condition:visual;reaction_time:0.6927207;trial_nr:24;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.866267
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:25;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.660492
# Processing annotation: box:touched;condition:visual;reaction_time:0.8375392;trial_nr:25;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.660492
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:26;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.119011
# Processing annotation: box:touched;condition:visual;reaction_time:0.5129428;trial_nr:26;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.119011
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:27;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.635723
# Processing annotation: box:touched;condition:visual;reaction_time:0.8822603;trial_nr:27;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.635723
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:28;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.065095
# Processing annotation: box:touched;condition:visual;reaction_time:0.7152419;trial_nr:28;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.065095
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:29;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.099202
# Processing annotation: box:touched;condition:visual;reaction_time:0.7262888;trial_nr:29;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.099202
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:30;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.480724
# Processing annotation: box:touched;condition:visual;reaction_time:0.5032773;trial_nr:30;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.480724
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:31;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.795825
# Processing annotation: box:touched;condition:visual;reaction_time:0.8823588;trial_nr:31;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.795825
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:32;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.692574
# Processing annotation: box:touched;condition:visual;reaction_time:0.782594;trial_nr:32;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.692574
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:33;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.073844
# Processing annotation: box:touched;condition:visual;reaction_time:0.771152;trial_nr:33;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.073844
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:34;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.100294
# Processing annotation: box:touched;condition:visual;reaction_time:1.162185;trial_nr:34;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.100294
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:35;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.249238
# Processing annotation: box:touched;condition:visual;reaction_time:0.5063295;trial_nr:35;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.249238
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:36;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.996564
# Processing annotation: box:touched;condition:visual;reaction_time:0.7485423;trial_nr:36;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.996564
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:37;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.280476
# Processing annotation: box:touched;condition:visual;reaction_time:0.5480824;trial_nr:37;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.280476
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:38;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.612237
# Processing annotation: box:touched;condition:visual;reaction_time:1.005575;trial_nr:38;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.612237
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:39;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.67156
# Processing annotation: box:touched;condition:visual;reaction_time:0.7488384;trial_nr:39;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.67156
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:40;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.329175
# Processing annotation: box:touched;condition:visual;reaction_time:0.5808659;trial_nr:40;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.329175
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:41;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.311179
# Processing annotation: box:touched;condition:visual;reaction_time:1.318143;trial_nr:41;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.311179
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:42;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.526772
# Processing annotation: box:touched;condition:visual;reaction_time:0.8269975;trial_nr:42;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.526772
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:43;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.285235
# Processing annotation: box:touched;condition:visual;reaction_time:0.7703707;trial_nr:43;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.285235
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:44;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.243349
# Processing annotation: box:touched;condition:visual;reaction_time:0.7151628;trial_nr:44;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.243349
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:45;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.818285
# Processing annotation: box:touched;condition:visual;reaction_time:0.7705493;trial_nr:45;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.818285
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:46;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.424383
# Processing annotation: box:touched;condition:visual;reaction_time:0.569654;trial_nr:46;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.424383
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:47;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.374848
# Processing annotation: box:touched;condition:visual;reaction_time:0.8042793;trial_nr:47;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.374848
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:48;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.97618
# Processing annotation: box:touched;condition:visual;reaction_time:0.9494815;trial_nr:48;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.97618
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:49;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.204314
# Processing annotation: box:touched;condition:visual;reaction_time:0.7818985;trial_nr:49;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.204314
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:50;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.539397
# Processing annotation: box:touched;condition:visual;reaction_time:0.6038365;trial_nr:50;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.539397
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:51;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.679407
# Processing annotation: box:touched;condition:visual;reaction_time:0.8721786;trial_nr:51;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.679407
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:52;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.670033
# Processing annotation: box:touched;condition:visual;reaction_time:0.827035;trial_nr:52;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.670033
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:53;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.01667
# Processing annotation: box:touched;condition:visual;reaction_time:0.681767;trial_nr:53;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.01667
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.219432
# Processing annotation: box:touched;condition:visual;reaction_time:0.6925492;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.219432
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:55;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.884362
# Processing annotation: box:touched;condition:visual;reaction_time:0.5476189;trial_nr:55;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.884362
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:56;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.627649
# Processing annotation: box:touched;condition:visual;reaction_time:0.7933173;trial_nr:56;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.627649
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:57;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.303178
# Processing annotation: box:touched;condition:visual;reaction_time:0.5144906;trial_nr:57;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.303178
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:58;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.320539
# Processing annotation: box:touched;condition:visual;reaction_time:0.848711;trial_nr:58;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.320539
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:59;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.750325
# Processing annotation: box:touched;condition:visual;reaction_time:0.8600876;trial_nr:59;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.750325
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:60;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.217133
# Processing annotation: box:touched;condition:visual;reaction_time:0.5366702;trial_nr:60;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.217133
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:61;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.432561
# Processing annotation: box:touched;condition:visual;reaction_time:0.5212007;trial_nr:61;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.432561
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:62;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.308105
# Processing annotation: box:touched;condition:visual;reaction_time:0.7487206;trial_nr:62;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.308105
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:63;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.863334
# Processing annotation: box:touched;condition:visual;reaction_time:0.6028206;trial_nr:63;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.863334
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:64;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.181757
# Processing annotation: box:touched;condition:visual;reaction_time:0.6483822;trial_nr:64;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.181757
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:65;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.301455
# Processing annotation: box:touched;condition:visual;reaction_time:0.6812782;trial_nr:65;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.301455
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:66;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.280791
# Processing annotation: box:touched;condition:visual;reaction_time:0.3336725;trial_nr:66;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.280791
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:67;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.163517
# Processing annotation: box:touched;condition:visual;reaction_time:0.5477576;trial_nr:67;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.163517
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:68;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.0393
# Processing annotation: box:touched;condition:visual;reaction_time:0.5142951;trial_nr:68;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.0393
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:69;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.589431
# Processing annotation: box:touched;condition:visual;reaction_time:1.318351;trial_nr:69;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.589431
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:70;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.548396
# Processing annotation: box:touched;condition:visual;reaction_time:0.4363861;trial_nr:70;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.548396
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:71;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.155846
# Processing annotation: box:touched;condition:visual;reaction_time:0.615252;trial_nr:71;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.155846
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:72;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.28705
# Processing annotation: box:touched;condition:visual;reaction_time:0.5249901;trial_nr:72;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.28705
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:73;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.437213
# Processing annotation: box:touched;condition:visual;reaction_time:0.736799;trial_nr:73;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.437213
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:74;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.675225
# Processing annotation: box:touched;condition:visual;reaction_time:0.7036433;trial_nr:74;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.675225
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:75;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.995058
# Processing annotation: box:touched;condition:visual;reaction_time:0.4134066;trial_nr:75;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.995058
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:76;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.107556
# Processing annotation: box:touched;condition:visual;reaction_time:0.7035298;trial_nr:76;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.107556
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:77;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.500026
# Processing annotation: box:touched;condition:visual;reaction_time:0.5366743;trial_nr:77;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.500026
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:78;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.423638
# Processing annotation: box:touched;condition:visual;reaction_time:0.7152317;trial_nr:78;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.423638
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:79;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.57677
# Processing annotation: box:touched;condition:visual;reaction_time:0.7038217;trial_nr:79;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.57677
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:80;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.060367
# Processing annotation: box:touched;condition:visual;reaction_time:0.514431;trial_nr:80;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.060367
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:81;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.97382
# Processing annotation: box:touched;condition:visual;reaction_time:0.5807931;trial_nr:81;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.97382
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:82;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.771158
# Processing annotation: box:touched;condition:visual;reaction_time:0.8711748;trial_nr:82;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.771158
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:83;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.618542
# Processing annotation: box:touched;condition:visual;reaction_time:0.6653247;trial_nr:83;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.618542
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:84;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.833408
# Processing annotation: box:touched;condition:visual;reaction_time:0.6253765;trial_nr:84;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.833408
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:85;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.663928
# Processing annotation: box:touched;condition:visual;reaction_time:0.7147024;trial_nr:85;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.663928
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:86;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.064766
# Processing annotation: box:touched;condition:visual;reaction_time:0.5487375;trial_nr:86;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.064766
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:87;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.537208
# Processing annotation: box:touched;condition:visual;reaction_time:0.6144187;trial_nr:87;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.537208
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:88;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.947829
# Processing annotation: box:touched;condition:visual;reaction_time:0.8376815;trial_nr:88;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.947829
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:89;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.771864
# Processing annotation: box:touched;condition:visual;reaction_time:0.7273777;trial_nr:89;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.771864
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:90;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.369039
# Processing annotation: box:touched;condition:visual;reaction_time:0.4467449;trial_nr:90;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.369039
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:91;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.201627
# Processing annotation: box:touched;condition:visual;reaction_time:0.8936856;trial_nr:91;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.201627
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:92;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.600814
# Processing annotation: box:touched;condition:visual;reaction_time:0.8484492;trial_nr:92;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.600814
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:93;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.573768
# Processing annotation: box:touched;condition:visual;reaction_time:0.8036883;trial_nr:93;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.573768
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:94;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.973174
# Processing annotation: box:touched;condition:visual;reaction_time:0.5367596;trial_nr:94;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.973174
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:95;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.39118
# Processing annotation: box:touched;condition:visual;reaction_time:0.5139322;trial_nr:95;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.39118
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:96;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.269404
# Processing annotation: box:touched;condition:visual;reaction_time:0.7391784;trial_nr:96;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.269404
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:97;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.042383
# Processing annotation: box:touched;condition:visual;reaction_time:0.4134655;trial_nr:97;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.042383
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:98;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.634204
# Processing annotation: box:touched;condition:visual;reaction_time:1.129021;trial_nr:98;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.634204
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:99;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.111393
# Processing annotation: box:touched;condition:visual;reaction_time:0.7385011;trial_nr:99;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.111393
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:100;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.777898
# Processing annotation: box:touched;condition:visual;reaction_time:0.5143857;trial_nr:100;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.777898
# Processing annotation: block:start;currentBlockNr:2;condition:visual;training:false
# Skipping irrelevant annotation: block:start;currentBlockNr:2;condition:visual;training:false
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:101;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.235522
# Processing annotation: box:touched;condition:visual;reaction_time:0.7049661;trial_nr:101;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.235522
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:102;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.278034
# Processing annotation: box:touched;condition:visual;reaction_time:0.6591477;trial_nr:102;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.278034
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:103;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.271817
# Processing annotation: box:touched;condition:visual;reaction_time:0.5582309;trial_nr:103;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.271817
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:104;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.449863
# Processing annotation: box:touched;condition:visual;reaction_time:0.6594689;trial_nr:104;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.449863
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:105;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.310235
# Processing annotation: box:touched;condition:visual;reaction_time:0.626472;trial_nr:105;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.310235
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:106;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.05736
# Processing annotation: box:touched;condition:visual;reaction_time:0.525207;trial_nr:106;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.05736
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:107;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.304455
# Processing annotation: box:touched;condition:visual;reaction_time:0.7164125;trial_nr:107;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.304455
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:108;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.305979
# Processing annotation: box:touched;condition:visual;reaction_time:0.8269105;trial_nr:108;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.305979
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:109;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.660474
# Processing annotation: box:touched;condition:visual;reaction_time:0.547864;trial_nr:109;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.660474
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:110;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.13383
# Processing annotation: box:touched;condition:visual;reaction_time:0.4915709;trial_nr:110;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.13383
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:visual;trial_nr:111;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.878947
# ...
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7494383;trial_nr:286;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.016887;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.7494383;trial_nr:286;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.016887
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1016672
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1016672
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:287;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.689096
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5469551;trial_nr:287;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.689096;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.5469551;trial_nr:287;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.689096
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004125
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004125
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:288;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.457489
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7152948;trial_nr:288;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.457489;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.7152948;trial_nr:288;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.457489
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1028998
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1028998
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:289;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.677394
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7372389;trial_nr:289;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.677394;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.7372389;trial_nr:289;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.677394
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.10016
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.10016
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:290;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.983825
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5698378;trial_nr:290;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.983825;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.5698378;trial_nr:290;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.983825
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1007573
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1007573
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:291;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.996617
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.228817;trial_nr:291;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.996617;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:1.228817;trial_nr:291;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.996617
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1051386
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1051386
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:292;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.110826
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.781867;trial_nr:292;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.110826;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.781867;trial_nr:292;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.110826
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1008446
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1008446
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:293;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.916885
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8373976;trial_nr:293;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.916885;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.8373976;trial_nr:293;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.916885
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1010042
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1010042
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:294;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.740421
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7151694;trial_nr:294;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.740421;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.7151694;trial_nr:294;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.740421
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1002702
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1002702
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:295;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.160765
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6137972;trial_nr:295;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.160765;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.6137972;trial_nr:295;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.160765
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1015289
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1015289
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:296;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.826607
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6806569;trial_nr:296;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.826607;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.6806569;trial_nr:296;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.826607
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1054309
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1054309
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:297;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.395857
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7709656;trial_nr:297;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.395857;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.7709656;trial_nr:297;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.395857
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1006491
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1006491
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:298;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.194648
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7486701;trial_nr:298;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.194648;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.7486701;trial_nr:298;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.194648
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.100493
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.100493
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:299;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.404389
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6370666;trial_nr:299;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.404389;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.6370666;trial_nr:299;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.404389
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004085
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1004085
# Processing annotation: visualFeedback:off
# Skipping irrelevant annotation: visualFeedback:off
# Processing annotation: box:spawned;condition:vibro;trial_nr:300;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.832153
# Processing annotation: box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.4912868;trial_nr:300;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.832153;vibro_duration:0.1
# Processing annotation: box:touched;condition:vibro;reaction_time:0.4912868;trial_nr:300;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.832153
# Processing annotation: vibroFeedback:off;vibroFeedbackDuration:0.1000383
# Skipping irrelevant annotation: vibroFeedback:off;vibroFeedbackDuration:0.1000383
# Processing annotation: ipq_question_nr_1_answer:5
# Skipping irrelevant annotation: ipq_question_nr_1_answer:5
# Processing annotation: ipq_question_nr_2_answer:5
# Skipping irrelevant annotation: ipq_question_nr_2_answer:5
# Processing annotation: ipq_question_nr_3_answer:2
# Skipping irrelevant annotation: ipq_question_nr_3_answer:2
# Processing annotation: ipq_question_nr_4_answer:4
# Skipping irrelevant annotation: ipq_question_nr_4_answer:4
# Processing annotation: block:end;currentBlockNr:3;condition:vibro;training:false
# Skipping irrelevant annotation: block:end;currentBlockNr:3;condition:vibro;training:false
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 643 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 643 events and 251 original time points ...
# /scratch/ipykernel_744126/2330229122.py:31: RuntimeWarning: Not setting position of 1 eog channel found in montage:
# ['Fp2']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw_referenced = raw_filtered.set_eeg_reference(ref_channels="average").set_montage("standard_1020")  # Re-reference
# 0 bad epochs dropped
# Total epochs: 643
# Fitting ICA to data using 63 channels (please be patient, this may take a while)
# /scratch/ipykernel_744126/2330229122.py:68: RuntimeWarning: The epochs you passed to ICA.fit() were baseline-corrected. However, we suggest to fit ICA only on data that has been high-pass filtered, but NOT baseline-corrected.
#   ica.fit(clean_epochs)
# Selecting by number: 10 components
# Fitting ICA took 9.6s.
# <MNEFigure size 975x496 with 10 Axes>
# /scratch/ipykernel_744126/2330229122.py:75: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   labels = label_components(raw_referenced, ica, method='iclabel')
# /scratch/ipykernel_744126/2330229122.py:75: RuntimeWarning: The provided ICA instance was fitted with a 'picard' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   labels = label_components(raw_referenced, ica, method='iclabel')
# ICLabel Results:
# Component 0: eye blink (Probability: 1.00)
# Component 1: eye blink (Probability: 1.00)
# Component 2: brain (Probability: 1.00)
# Component 3: channel noise (Probability: 0.89)
# Component 4: brain (Probability: 0.76)
# Component 5: brain (Probability: 0.52)
# Component 6: brain (Probability: 0.94)
# Component 7: muscle artifact (Probability: 0.97)
# Component 8: brain (Probability: 0.51)
# Component 9: brain (Probability: 0.99)
# Applying ICA to Raw instance
#     Transforming to ICA space (10 components)
#     Zeroing out 3 ICA components
#     Projecting back using 63 PCA components
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.2 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.20
# - Lower transition bandwidth: 0.20 Hz (-6 dB cutoff frequency: 0.10 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 4125 samples (16.500 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Channel Fz: Negativity peak at 0.140 s with amplitude -0.000 µV
# Channel Cz: Negativity peak at 0.140 s with amplitude -0.000 µV
# Channel Fp1: Negativity peak at 0.244 s with amplitude -0.000 µV
# Channel FC1: Negativity peak at 0.140 s with amplitude -0.000 µV
# Channel FC2: Negativity peak at 0.140 s with amplitude -0.000 µV
# Match trials: 477, Mismatch trials: 166
# NOTE: tfr_morlet() is a legacy function. New code should use .compute_tfr(method="morlet").
# NOTE: tfr_morlet() is a legacy function. New code should use .compute_tfr(method="morlet").
